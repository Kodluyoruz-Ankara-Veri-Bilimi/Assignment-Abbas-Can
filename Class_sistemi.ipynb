# %%
import pandas as pd
import numpy as np
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

import seaborn as sns
import matplotlib.pyplot as plt


from scipy.stats import shapiro
from sklearn import metrics
from sklearn.metrics import mean_squared_error 
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
        
from statsmodels.stats.outliers_influence import variance_inflation_factor



from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict
import statsmodels.api as sm
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from yellowbrick.cluster import KElbowVisualizer



import statsmodels.api as sm
import statsmodels.formula.api as smf
        
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
        
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor




import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
        
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
        




class bilgi():
    
    def __init__(self):
        ...
        
    def tanimlayici_ist(self):
        # Tanımlayıcı istatistik bilgilerini bize gösterir.
        a = self.veri.describe()
        print(a)
    def on_bilgi(self):
        # Veri seti hakkında bize genel bir bilgi verir.
        a = self.head()
        b = self.dtypes
        print(a,b)
        
class duzenleme():  
    
    def __init__(self, veri):
        pass
        

    def bos_gozlem(self):
        a = self.isnull().sum()  
        print(a)
        
    def bos_kaldir(self):
        self.dropna(inplace = True)
    
    def gozlum_doldur():
        self.fillna(self.mean(), inplace = True)
    

class testler():
    def __init__(self):
        pass

    
    def guven_araligi(data, confidence=0.95):
        a = 1.0 * np.array(data)
        n = len(a)
        m, se = np.mean(a), scipy.stats.sem(a)
        h = se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)
        return m, m-h, m+h
    
    def shapiro(self):
        stat, p = shapiro(self)

        print('Statistics=%.3f, p=%.3f' % (stat, p))

        alpha = 0.05
        if p > alpha:
                print('Dağılım normalden geliyor (H0 reddedilemez)')
        else:
                print('Normal dağılımdan gelmiyor (H0 reddedilir)')
        
        
class gorsel():
    def __init__(self, x, y, veri):
        pass

    def kutu(x,y, veri):
        ax = sns.barplot(x, y, data= veri)
        
        return ax
    
    
    def count(self):
        sns.countplot(self)
        
        
class model_oncesi():
    
    def __init__(self, x, y, veri):
        pass
        
        
        
    def P_C_A(self, y2, p_c_a_sayisi):
        X_dummies = pd.get_dummies(self)
        X = X_dummies.drop([y2], axis = 1)
        y = self[y2]             
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)  
        
        pca = PCA(n_components= p_c_a_sayisi)
        
        X_reduced_train = pca.fit_transform(scale(X_train))
        X_reduced_test = pca.fit_transform(scale(X_test))
        
        
        data_pca = pca.fit_transform(scale(X_dummies))
        data_pca = pd.DataFrame(data_pca)
        
        
        print(np.cumsum(np.round(pca.explained_variance_ratio_, decimals = 4) * 100))
        
        
    def kumeleme_pca(self, kume_sayisi, p_c_a_sayisi):
        X_dummies = pd.get_dummies(self)
        
        pca = PCA(n_components= p_c_a_sayisi)
        
        data_pca = pca.fit_transform(scale(X_dummies))
        data_pca = pd.DataFrame(data_pca)
        
        
        kmeans = KMeans(n_clusters= kume_sayisi)
        k_fit = kmeans.fit(data_pca)
        kumeler = k_fit.labels_
        merkezler = k_fit.cluster_centers_
        
        print("Kümeler: {}\n\n Merkezler: {}".format(kumeler, merkezler))
        
        
        plt.scatter(data_pca.iloc[:,0], data_pca.iloc[:,1], merkezler, c= kumeler,  cmap = "viridis")
        plt.scatter(merkezler[:,0], merkezler[:,1], c="black", s= 200, alpha = 0.5)
            
        
    def kumeleme(self, kume_sayisi):
        X_dummies = pd.get_dummies(self)
        kmeans = KMeans(n_clusters= kume_sayisi)
        k_fit = kmeans.fit(X_dummies)
        kumeler = k_fit.labels_
        merkezler = k_fit.cluster_centers_
        
        print("Kümeler: {}\n\n Merkezler: {}".format(kumeler, merkezler))
        
        
        plt.scatter(X_dummies.iloc[:,0], X_dummies.iloc[:,1], merkezler, c= kumeler,  cmap = "viridis")
        plt.scatter(merkezler[:,0], merkezler[:,1], c="black", s= 200, alpha = 0.5)
        
        
        
        
    def optimum_kume(self):
        
        df_dummies = pd.get_dummies(self)
        kmeans = KMeans()
        k_fit = kmeans.fit(df_dummies)
        visualizer = KElbowVisualizer(kmeans, k=(2,50))

        visualizer.fit(df_dummies)

        visualizer.poof()
        
        
class regressor_problemi():
    
    def __init__(self):
        pass

        from statsmodels.stats.outliers_influence import variance_inflation_factor
        
    def calc_vif(X):

       
        vif = pd.DataFrame()
        vif["variables"] = X.columns
        vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

        return(vif)
    
    
    def linear_regresyon(self,y2):
        X_dummies = pd.get_dummies(self)
        X = X_dummies.drop([y2], axis = 1)
        X = sm.add_constant(X)
        y = self[y2]             
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)  
        ols_model = sm.OLS(y_train, X_train.astype(float))
        ols_results = ols_model.fit()
        print(ols_results.summary()) 
        
    def  DecisionTree_Regressor(self, y2):  
        X_dummies = pd.get_dummies(self)
        X = X_dummies.drop([y2], axis = 1)
        y = self[y2]             
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)  
        
        cart = DecisionTreeRegressor()
        cart_model = cart.fit(X_train, y_train)
        y_pred = cart_model.predict(X_test)
        
        mse = np.sqrt(mean_squared_error(y_test, y_pred))
        r2 = r2_score(y_test, y_pred)
        

        print("rmse: {} \nr2: {}\n".format(mse,r2, ))
        
        
    def RandomForest_Regressor(self, y2):
        X_dummies = pd.get_dummies(self)
        X = X_dummies.drop([y2], axis = 1)
        y = self[y2]             
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)  
        
        rf = RandomForestRegressor()
        rf_model = rf.fit(X_train, y_train)
        y_pred = rf_model.predict(X_test)
        
        mse = np.sqrt(mean_squared_error(y_test, y_pred))
        r2 = r2_score(y_test, y_pred)
        

        print("rmse: {} \nr2: {}\n".format(mse,r2, ))
        
        
        
    def  MLP_Regressor(self, y2):
        X_dummies = pd.get_dummies(self)
        X = X_dummies.drop([y2], axis = 1)
        y = self[y2] 
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42) 
        
        mlp = MLPRegressor(hidden_layer_sizes=(100, 20))
        mlp_model = mlp.fit(X_train, y_train)    
        y_pred = mlp_model.predict(X_test)
        
        mse = np.sqrt(mean_squared_error(y_test, y_pred))
        r2 = r2_score(y_test, y_pred)
        

        print("rmse: {} \nr2: {}\n".format(mse,r2, ))
        
        
        
    def  S_V_R(self, y2):
        X_dummies = pd.get_dummies(self)
        X = X_dummies.drop([y2], axis = 1)
        y = self[y2] 
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42) 
        
        svr = SVR()
        svr_model = svr.fit(X_train, y_train)    
        y_pred = svr_model.predict(X_test)
        
        mse = np.sqrt(mean_squared_error(y_test, y_pred))
        r2 = r2_score(y_test, y_pred)
        

        print("rmse: {} \nr2: {}\n".format(mse,r2, ))
        

  
        
    def  GradientBoosting_Regressor(self, y2):
        X_dummies = pd.get_dummies(self)
        X = X_dummies.drop([y2], axis = 1)
        y = self[y2] 
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42) 
        
        gbr = GradientBoostingRegressor()
        gbr_model = gbr.fit(X_train, y_train)    
        y_pred = gbr_model.predict(X_test)
        
        mse = np.sqrt(mean_squared_error(y_test, y_pred))
        r2 = r2_score(y_test, y_pred)
        

        print("rmse: {} \nr2: {}\n".format(mse,r2, ))
        
           
    def  XGB_Regressor(self, y2):  
        X_dummies = pd.get_dummies(self)
        X = X_dummies.drop([y2], axis = 1)
        y = self[y2]             
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)  
        
        xgbr = XGBRegressor()
        xgbr_model = xgbr.fit(X_train, y_train)
        y_pred = xgbr_model.predict(X_test)
        
        mse = np.sqrt(mean_squared_error(y_test, y_pred))
        r2 = r2_score(y_test, y_pred)
        

        print("rmse: {} \nr2: {}\n".format(mse,r2, ))
        
         
    def  lGBM_Regressor(self, y2):  
        X_dummies = pd.get_dummies(self)
        X = X_dummies.drop([y2], axis = 1)
        y = self[y2]             
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)  
        
        lgmr = XGBRegressor()
        lgmr_model = lgmr.fit(X_train, y_train)
        y_pred = lgmr_model.predict(X_test)
        
        mse = np.sqrt(mean_squared_error(y_test, y_pred))
        r2 = r2_score(y_test, y_pred)
        

        print("rmse: {} \nr2: {}\n".format(mse,r2, ))
        

    def  CatBoost_Regressor(self, y2):  
        X_dummies = pd.get_dummies(self)
        X = X_dummies.drop([y2], axis = 1)
        y = self[y2]             
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)  
        
        catbr = XGBRegressor()
        catbr_model = catbr.fit(X_train, y_train)
        y_pred = catbr_model.predict(X_test)
        
        mse = np.sqrt(mean_squared_error(y_test, y_pred))
        r2 = r2_score(y_test, y_pred)
        

        print("rmse: {} \nr2: {}\n".format(mse,r2, ))
        

        
  
    def   KNeighbors_Regressor(self, y2):  
        X_dummies = pd.get_dummies(self)
        X = X_dummies.drop([y2], axis = 1)
        y = self[y2]             
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)  
        
        knnr =  KNeighborsRegressor()
        knnr_model = knnr.fit(X_train, y_train)
        y_pred = knnr_model.predict(X_test)
        
        
        mse = np.sqrt(mean_squared_error(y_test, y_pred))
        r2 = r2_score(y_test, y_pred)
        

        print("rmse: {} \nr2: {}\n".format(mse,r2, ))
        

        


            
            
class classfication_problemi():
    
    def __init__(self):
        pass
        
    def calc_vif(X):

       
        vif = pd.DataFrame()
        vif["variables"] = X.columns
        vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

        return(vif)
    
    def Logistic_regression(self, y2):
        
        X_dummies = pd.get_dummies(self)
        X = X_dummies.drop([y2], axis = 1)
        y = self[y2] 
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42) 
        
        logi = LogisticRegression()
        logi_model = logi.fit(X_train, y_train)
        y_pred = logi_model.predict(X_test)
        
        
        ac = metrics.accuracy_score(y_test, y_pred)
        con_matrix = confusion_matrix(y_test, y_pred)
        clas_report = classification_report(y_test, y_pred)
        

        print("Accuracy Score: {} \nConfusion Matrix: \n{}\n*********************************\nClassification Report: \n{}".format(ac,con_matrix, clas_report))
        
        probs = logi_model.predict_proba(X_test)
        preds = probs[:,1]
        fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
        roc_auc = metrics.auc(fpr, tpr)


        
        plt.title('Receiver Operating Characteristic')
        plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
        plt.legend(loc = 'lower right')
        plt.plot([0, 1], [0, 1],'r--')
        plt.xlim([0, 1])
        plt.ylim([0, 1])
        plt.ylabel('True Positive Rate')
        plt.xlabel('False Positive Rate')
        plt.show()

    def DecisionTree_Classifier(self, y2):
                
    
        X_dummies = pd.get_dummies(self)
        X = X_dummies.drop([y2], axis = 1)
        y = self[y2] 
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42) 
        
        cart = DecisionTreeClassifier()
        cart_model = cart.fit(X_train, y_train)
        y_pred = cart_model.predict(X_test)
        
        ac = metrics.accuracy_score(y_test, y_pred)
        con_matrix = confusion_matrix(y_test, y_pred)
        clas_report = classification_report(y_test, y_pred)
        

        print("Accuracy Score: {} \nConfusion Matrix: \n{}\n*********************************\nClassification Report: \n{}".format(ac,con_matrix, clas_report))
        
        
        probs = cart_model.predict_proba(X_test)
        preds = probs[:,1]
        fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
        roc_auc = metrics.auc(fpr, tpr)


        
        plt.title('Receiver Operating Characteristic')
        plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
        plt.legend(loc = 'lower right')
        plt.plot([0, 1], [0, 1],'r--')
        plt.xlim([0, 1])
        plt.ylim([0, 1])
        plt.ylabel('True Positive Rate')
        plt.xlabel('False Positive Rate')
        plt.show()
        
        
    def RandomForest_Classifier(self, y2):
              
        X_dummies = pd.get_dummies(self)
        X = X_dummies.drop([y2], axis = 1)
        y = self[y2] 
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)
              
        rf = RandomForestClassifier()
        rf_model = rf.fit(X_train, y_train)
        y_pred = rf_model.predict(X_test)
              
        ac = metrics.accuracy_score(y_test, y_pred)
        con_matrix = confusion_matrix(y_test, y_pred)
        clas_report = classification_report(y_test, y_pred)
        

        print("Accuracy Score: {} \nConfusion Matrix: \n{}\n*********************************\nClassification Report: \n{}".format(ac,con_matrix, clas_report))
        
        
        probs = rf_model.predict_proba(X_test)
        preds = probs[:,1]
        fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
        roc_auc = metrics.auc(fpr, tpr)


        
        plt.title('Receiver Operating Characteristic')
        plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
        plt.legend(loc = 'lower right')
        plt.plot([0, 1], [0, 1],'r--')
        plt.xlim([0, 1])
        plt.ylim([0, 1])
        plt.ylabel('True Positive Rate')
        plt.xlabel('False Positive Rate')
        plt.show()
        
        
    def MLP_Classifier(self, y2):
        
        X_dummies = pd.get_dummies(self)
        X = X_dummies.drop([y2], axis = 1)
        y = self[y2] 
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42) 
        
        mlp = MLPClassifier()
        mlp_model = mlp.fit(X_train, y_train)
        y_pred = mlp_model.predict(X_test)
        
        
        ac = metrics.accuracy_score(y_test, y_pred)
        con_matrix = confusion_matrix(y_test, y_pred)
        clas_report = classification_report(y_test, y_pred)
        

        print("Accuracy Score: {} \nConfusion Matrix: \n{}\n*********************************\nClassification Report: \n{}".format(ac,con_matrix, clas_report))
        
        
        probs = mlp_model.predict_proba(X_test)
        preds = probs[:,1]
        fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
        roc_auc = metrics.auc(fpr, tpr)


        
        plt.title('Receiver Operating Characteristic')
        plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
        plt.legend(loc = 'lower right')
        plt.plot([0, 1], [0, 1],'r--')
        plt.xlim([0, 1])
        plt.ylim([0, 1])
        plt.ylabel('True Positive Rate')
        plt.xlabel('False Positive Rate')
        plt.show()
        
        
    def S_V_C(self, y2):
        
        X_dummies = pd.get_dummies(self)
        X = X_dummies.drop([y2], axis = 1)
        y = self[y2] 
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42) 
        
        svc = SVC()
        svc_model = svc.fit(X_train, y_train)
        y_pred = svc_model.predict(X_test)
        
        
        ac = metrics.accuracy_score(y_test, y_pred)
        con_matrix = confusion_matrix(y_test, y_pred)
        clas_report = classification_report(y_test, y_pred)
        

        print("Accuracy Score: {} \nConfusion Matrix: \n{}\n*********************************\nClassification Report: \n{}".format(ac,con_matrix, clas_report))
        
        
        probs = svc_model.predict_proba(X_test)
        preds = probs[:,1]
        fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
        roc_auc = metrics.auc(fpr, tpr)


        
        plt.title('Receiver Operating Characteristic')
        plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
        plt.legend(loc = 'lower right')
        plt.plot([0, 1], [0, 1],'r--')
        plt.xlim([0, 1])
        plt.ylim([0, 1])
        plt.ylabel('True Positive Rate')
        plt.xlabel('False Positive Rate')
        plt.show()
        
        
    def GradientBoosting_Classifier(self, y2):
        
        X_dummies = pd.get_dummies(self)
        X = X_dummies.drop([y2], axis = 1)
        y = self[y2] 
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42) 
        
        gbc = GradientBoostingClassifier()
        gbc_model = gbc.fit(X_train, y_train)
        y_pred = gbc_model.predict(X_test)
        
        
        ac = metrics.accuracy_score(y_test, y_pred)
        con_matrix = confusion_matrix(y_test, y_pred)
        clas_report = classification_report(y_test, y_pred)
        

        print("Accuracy Score: {} \nConfusion Matrix: \n{}\n*********************************\nClassification Report: \n{}".format(ac,con_matrix, clas_report))
        
        probs = gbc_model.predict_proba(X_test)
        preds = probs[:,1]
        fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
        roc_auc = metrics.auc(fpr, tpr)


        
        plt.title('Receiver Operating Characteristic')
        plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
        plt.legend(loc = 'lower right')
        plt.plot([0, 1], [0, 1],'r--')
        plt.xlim([0, 1])
        plt.ylim([0, 1])
        plt.ylabel('True Positive Rate')
        plt.xlabel('False Positive Rate')
        plt.show()
        
        
    def XGB_Classifier(self, y2):
        
        X_dummies = pd.get_dummies(self)
        X = X_dummies.drop([y2], axis = 1)
        y = self[y2] 
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42) 
        
        xgbc = XGBClassifier()
        xgbc_model = xgbc.fit(X_train, y_train)
        y_pred = xgbc_model.predict(X_test)
        
        ac = metrics.accuracy_score(y_test, y_pred)
        con_matrix = confusion_matrix(y_test, y_pred)
        clas_report = classification_report(y_test, y_pred)
        

        print("Accuracy Score: {} \nConfusion Matrix: \n{}\n*********************************\nClassification Report: \n{}".format(ac,con_matrix, clas_report))
    
    
        probs = xgbc_model.predict_proba(X_test)
        preds = probs[:,1]
        fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
        roc_auc = metrics.auc(fpr, tpr)


        
        plt.title('Receiver Operating Characteristic')
        plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
        plt.legend(loc = 'lower right')
        plt.plot([0, 1], [0, 1],'r--')
        plt.xlim([0, 1])
        plt.ylim([0, 1])
        plt.ylabel('True Positive Rate')
        plt.xlabel('False Positive Rate')
        plt.show()
        
        
    def LGBM_Classifier(self, y2):
        
        X_dummies = pd.get_dummies(self)
        X = X_dummies.drop([y2], axis = 1)
        y = self[y2] 
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42) 
        
        lgmbc = LGBMClassifier()
        lgmbc_model = lgmbc.fit(X_train, y_train)
        y_pred = lgmbc_model.predict(X_test)
        
        
        ac = metrics.accuracy_score(y_test, y_pred)
        con_matrix = confusion_matrix(y_test, y_pred)
        clas_report = classification_report(y_test, y_pred)
        

        print("Accuracy Score: {} \nConfusion Matrix: \n{}\n*********************************\nClassification Report: \n{}".format(ac,con_matrix, clas_report))
        
        probs = lgmbc_model.predict_proba(X_test)
        preds = probs[:,1]
        fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
        roc_auc = metrics.auc(fpr, tpr)


        
        plt.title('Receiver Operating Characteristic')
        plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
        plt.legend(loc = 'lower right')
        plt.plot([0, 1], [0, 1],'r--')
        plt.xlim([0, 1])
        plt.ylim([0, 1])
        plt.ylabel('True Positive Rate')
        plt.xlabel('False Positive Rate')
        plt.show()
        
        
    def CatBoost_Classifier(self, y2):
        
        X_dummies = pd.get_dummies(self)
        X = X_dummies.drop([y2], axis = 1)
        y = self[y2] 
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42) 
        
        catbc = CatBoostClassifier()
        catbc_model = catbc.fit(X_train, y_train)
        y_pred = catbc_model.predict(X_test)
        
        
        ac = metrics.accuracy_score(y_test, y_pred)
        con_matrix = confusion_matrix(y_test, y_pred)
        clas_report = classification_report(y_test, y_pred)
        

        print("Accuracy Score: {} \nConfusion Matrix: \n{}\n*********************************\nClassification Report: \n{}".format(ac,con_matrix, clas_report))
        
        probs = catbc_model.predict_proba(X_test)
        preds = probs[:,1]
        fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
        roc_auc = metrics.auc(fpr, tpr)


        
        plt.title('Receiver Operating Characteristic')
        plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
        plt.legend(loc = 'lower right')
        plt.plot([0, 1], [0, 1],'r--')
        plt.xlim([0, 1])
        plt.ylim([0, 1])
        plt.ylabel('True Positive Rate')
        plt.xlabel('False Positive Rate')
        plt.show()
        
        
    def K_N_N(self, y2):
        
        X_dummies = pd.get_dummies(self)
        X = X_dummies.drop([y2], axis = 1)
        y = self[y2] 
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42) 
        
        knn = KNeighborsClassifier()
        knn_model = knn.fit(X_train, y_train)
        y_pred = knn_model.predict(X_test)
        
        
        ac = metrics.accuracy_score(y_test, y_pred)
        con_matrix = confusion_matrix(y_test, y_pred)
        clas_report = classification_report(y_test, y_pred)
        

        print("Accuracy Score: {} \nConfusion Matrix: \n{}\n*********************************\nClassification Report: \n{}".format(ac,con_matrix, clas_report))
             
        
        probs = knn_model.predict_proba(X_test)
        preds = probs[:,1]
        fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
        roc_auc = metrics.auc(fpr, tpr)


        
        plt.title('Receiver Operating Characteristic')
        plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
        plt.legend(loc = 'lower right')
        plt.plot([0, 1], [0, 1],'r--')
        plt.xlim([0, 1])
        plt.ylim([0, 1])
        plt.ylabel('True Positive Rate')
        plt.xlabel('False Positive Rate')
        plt.show()
        
        
class Grid_Search():
    
        def __init__(self):
            pass
            
        def K_N_N_grid(self, y2):
        
            X_dummies = pd.get_dummies(self)
            X = X_dummies.drop([y2], axis = 1)
            y = self[y2] 
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42) 
            
            
            knn = KNeighborsClassifier()
            knn_model = knn.fit(X_train, y_train)
            y_pred = knn_model.predict(X_test)
            
            grid_params = {'n_neighbors': np.arange(1, 40),
                                'metric': ['minkowski', 'euclidean', 'manhattan']}
            
            knn_cv = GridSearchCV(knn, grid_params, n_jobs = -1, verbose = 2)
            knn_model_cv = knn_cv.fit(X_train, y_train)
                    
            parametre = []
            
            for i in knn_model_cv.best_params_:
                parametre.append(knn_model_cv.best_params_[i])
            
            knn_model_tuned = KNeighborsClassifier(n_neighbors = parametre[1],
                                            metric = parametre[0]).fit(X_train, y_train)
            
            y_pred_tuned = knn_model_tuned.predict(X_test)
        
            ac = metrics.accuracy_score(y_test, y_pred)
            clas_report = classification_report(y_test, y_pred)
            
            ac_tuned = metrics.accuracy_score(y_test, y_pred_tuned)
            clas_report_tuned = classification_report(y_test, y_pred_tuned)
        

            print("Accuracy Score: {} \n\n*********************************\nClassification Report: \n{} \n\n <------------------------------->\n\n\nAccuracy Score Tuned: {} \n*********************************\nClassification Report Tuned: \n{}".format(ac, clas_report,ac_tuned, clas_report_tuned))
             
        
            probs = knn_model.predict_proba(X_test)
            preds = probs[:,1]
            fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
            roc_auc = metrics.auc(fpr, tpr)


        
            plt.title('Receiver Operating Characteristic')
            plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
            plt.legend(loc = 'lower right')
            plt.plot([0, 1], [0, 1],'r--')
            plt.xlim([0, 1])
            plt.ylim([0, 1])
            plt.ylabel('True Positive Rate')
            plt.xlabel('False Positive Rate')
            plt.show()
        
        def CatBoost_Classifier_grid(self, y2):
        
            X_dummies = pd.get_dummies(self)
            X = X_dummies.drop([y2], axis = 1)
            y = self[y2] 
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42) 
            
            
            catbc = CatBoostClassifier()
            catbc_model = catbc.fit(X_train, y_train)
            y_pred = catbc_model.predict(X_test)
            
            grid_params = {'iterations': [200, 500],
                            'learning_rate': [0.01, 0.02, 0.05],
                            'depth': [3, 5, 8]}
            
            catbc_cv = GridSearchCV(catbc, grid_params, n_jobs = -1, verbose = 2)
            catbc_model_cv = catbc_cv.fit(X_train, y_train)
                    
            parametre = []
            
            for i in catbc_model_cv.best_params_:
                parametre.append(catbc_model_cv.best_params_[i])
            
            catbc_model_tuned = CatBoostClassifier(iterations = parametre[2],
                                            learning_rate = parametre[1],
                                                  depth= parametre[0]).fit(X_train, y_train)
            
            y_pred_tuned = catbc_model_tuned.predict(X_test)
            probs = catbc_model.predict_proba(X_test)
            
        
            ac = metrics.accuracy_score(y_test, y_pred)
            clas_report = classification_report(y_test, y_pred)
            
            ac_tuned = metrics.accuracy_score(y_test, y_pred_tuned)
            clas_report_tuned = classification_report(y_test, y_pred_tuned)
        

            print("Accuracy Score: {} \n\n*********************************\nClassification Report: \n{} \n\n <------------------------------->\n\n\nAccuracy Score Tuned: {} \n*********************************\nClassification Report Tuned: \n{}".format(ac, clas_report,ac_tuned, clas_report_tuned))
             
            
            preds = probs[:,1]
            fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
            roc_auc = metrics.auc(fpr, tpr)


        
            plt.title('Receiver Operating Characteristic')
            plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
            plt.legend(loc = 'lower right')
            plt.plot([0, 1], [0, 1],'r--')
            plt.xlim([0, 1])
            plt.ylim([0, 1])
            plt.ylabel('True Positive Rate')
            plt.xlabel('False Positive Rate')
            plt.show()
            
            
        def LGBM_Classifier_grid(self, y2):
        
            X_dummies = pd.get_dummies(self)
            X = X_dummies.drop([y2], axis = 1)
            y = self[y2] 
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42) 
            
            
            lgbmc = LGBMClassifier()
            lgbmc_model = lgbmc.fit(X_train, y_train)
            y_pred = lgbmc_model.predict(X_test)
            
            grid_params = {'subsample': [0.6, 0.8, 1.0],
                               'n_estimators': [100, 500, 1000, 1500],
                               'max_depth': [4, 5, 6, 7],
                               'min_child_samples': [10, 20],
                               'learning_rate': [0.2, 0.1, 0.01, 0.02, 0.05]}
            
            lgbmc_cv = GridSearchCV(lgbmc, grid_params, n_jobs = -1, verbose = 2)
            lgbmc_model_cv = lgbmc_cv.fit(X_train, y_train)
                    
            parametre = []
            
            for i in lgbmc_model_cv.best_params_:
                parametre.append(lgbmc_model_cv.best_params_[i])
            
            lgbmc_model_tuned = LGBMClassifier(subsample = parametre[4],
                                            n_estimators = parametre[3],
                                                  max_depth= parametre[1],
                                                  min_child_samples= parametre[2],
                                                 learning_rate= parametre[0]).fit(X_train, y_train)
            
            y_pred_tuned = lgbmc_model_tuned.predict(X_test)
            probs = lgbmc_model.predict_proba(X_test)
        
        
            ac = metrics.accuracy_score(y_test, y_pred)
            clas_report = classification_report(y_test, y_pred)
            
            ac_tuned = metrics.accuracy_score(y_test, y_pred_tuned)
            clas_report_tuned = classification_report(y_test, y_pred_tuned)
        

            print("Accuracy Score: {} \n\n*********************************\nClassification Report: \n{} \n\n <------------------------------->\n\n\nAccuracy Score Tuned: {} \n*********************************\nClassification Report Tuned: \n{}".format(ac, clas_report,ac_tuned, clas_report_tuned))
             
        
            
            preds = probs[:,1]
            fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
            roc_auc = metrics.auc(fpr, tpr)


        
            plt.title('Receiver Operating Characteristic')
            plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
            plt.legend(loc = 'lower right')
            plt.plot([0, 1], [0, 1],'r--')
            plt.xlim([0, 1])
            plt.ylim([0, 1])
            plt.ylabel('True Positive Rate')
            plt.xlabel('False Positive Rate')
            plt.show()
            
            
        def XGB_Classifier_grid(self, y2):
        
            X_dummies = pd.get_dummies(self)
            X = X_dummies.drop([y2], axis = 1)
            y = self[y2] 
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42) 
            
            
            xgbc = XGBClassifier()
            xgbc_model = xgbc.fit(X_train, y_train)
            y_pred = xgbc_model.predict(X_test)
            
            grid_params = {'colsample_bytree':[0.6,1.0],
                        'n_estimators':[100,200,500,1000],
                        'max_depth':[4,5,6, 7],
                        'min_child_weight':[0.8,0.9,1],
                        'learning_rate': [0.1,0.01,0.02,0.05]}
            
            xgbc_cv = GridSearchCV(xgbc, grid_params, n_jobs = -1, verbose = 2)
            xgbc_model_cv = xgbc_cv.fit(X_train, y_train)
                    
            parametre = []
            
            for i in xgbc_model_cv.best_params_:
                parametre.append(xgbc_model_cv.best_params_[i])
            
            xgbc_model_tuned = XGBClassifier(colsample_bytree = parametre[0],
                                            n_estimators = parametre[4],
                                                  max_depth= parametre[2],
                                                  min_child_weight= parametre[3],
                                                 learning_rate= parametre[1]).fit(X_train, y_train)
            
            y_pred_tuned = xgbc_model_tuned.predict(X_test)
            probs = xgbc_model.predict_proba(X_test)
        
        
        
    
        
            ac = metrics.accuracy_score(y_test, y_pred)
            clas_report = classification_report(y_test, y_pred)
            
            ac_tuned = metrics.accuracy_score(y_test, y_pred_tuned)
            clas_report_tuned = classification_report(y_test, y_pred_tuned)
        

            print("Accuracy Score: {} \n\n*********************************\nClassification Report: \n{} \n\n <------------------------------->\n\n\nAccuracy Score Tuned: {} \n*********************************\nClassification Report Tuned: \n{}".format(ac, clas_report,ac_tuned, clas_report_tuned))
             
        
            
            preds = probs[:,1]
            fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
            roc_auc = metrics.auc(fpr, tpr)


        
            plt.title('Receiver Operating Characteristic')
            plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
            plt.legend(loc = 'lower right')
            plt.plot([0, 1], [0, 1],'r--')
            plt.xlim([0, 1])
            plt.ylim([0, 1])
            plt.ylabel('True Positive Rate')
            plt.xlabel('False Positive Rate')
            plt.show()   
            
        def GradientBoosting_Classifier_grid(self, y2):
        
            X_dummies = pd.get_dummies(self)
            X = X_dummies.drop([y2], axis = 1)
            y = self[y2] 
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42) 
            
            
            gbc = GradientBoostingClassifier()
            gbc_model = gbc.fit(X_train, y_train)
            y_pred = gbc_model.predict(X_test)
            
            grid_params = {'learning_rate': [0.001, 0.01, 0.1, 0.2, 0.3],
                            'n_estimators': [100, 500, 1000, 1500],
                            'max_depth': [3, 5, 6],
                            'min_samples_split': [2, 5, 10, 15],
                            'subsample':[0.6,1.0]}
            
            gbc_cv = GridSearchCV(gbc, grid_params, n_jobs = -1, verbose = 2)
            gbc_model_cv = gbc_cv.fit(X_train, y_train)
                    
            parametre = []
            
            for i in gbc_model_cv.best_params_:
                parametre.append(gbc_model_cv.best_params_[i])
            
            gbc_model_tuned = GradientBoostingClassifier(learning_rate = parametre[0],
                                            n_estimators = parametre[3],
                                                  max_depth = parametre[1],
                                                  min_samples_split = parametre[2],
                                                 subsample = parametre[4]).fit(X_train, y_train)
            
            y_pred_tuned = gbc_model_tuned.predict(X_test)
            probs = gbc_model.predict_proba(X_test)
        
        
        
    
        
            ac = metrics.accuracy_score(y_test, y_pred)
            clas_report = classification_report(y_test, y_pred)
            
            ac_tuned = metrics.accuracy_score(y_test, y_pred_tuned)
            clas_report_tuned = classification_report(y_test, y_pred_tuned)
        

            print("Accuracy Score: {} \n\n*********************************\nClassification Report: \n{} \n\n <------------------------------->\n\n\nAccuracy Score Tuned: {} \n*********************************\nClassification Report Tuned: \n{}".format(ac, clas_report,ac_tuned, clas_report_tuned))
             
        
            
            preds = probs[:,1]
            fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
            roc_auc = metrics.auc(fpr, tpr)


        
            plt.title('Receiver Operating Characteristic')
            plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
            plt.legend(loc = 'lower right')
            plt.plot([0, 1], [0, 1],'r--')
            plt.xlim([0, 1])
            plt.ylim([0, 1])
            plt.ylabel('True Positive Rate')
            plt.xlabel('False Positive Rate')
            plt.show()  
            
        def S_V_C_grid(self, y2):
        
            X_dummies = pd.get_dummies(self)
            X = X_dummies.drop([y2], axis = 1)
            y = self[y2] 
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42) 
            
            
            s_vc = SVC()
            s_vc_model = s_vc.fit(X_train, y_train)
            y_pred = s_vc_model.predict(X_test)
            
            grid_params = {"kernel": ["linear", 'poly', 'rbf'],
                             "C": [1,2,3,6,8]}
            
            s_vc_cv = GridSearchCV(s_vc, grid_params, n_jobs = -1, verbose = 2)
            s_vc_model_cv = s_vc_cv.fit(X_train, y_train)
                    
            parametre = []
            
            for i in s_vc_model_cv.best_params_:
                parametre.append(s_vc_model_cv.best_params_[i])
            
            s_vc_model_tuned = SVC(kernel = parametre[1],
                                            C = parametre[0]).fit(X_train, y_train)
            
            y_pred_tuned = s_vc_model_tuned.predict(X_test)
            probs = s_vc_model.predict_proba(X_test)
        
        
        
    
        
            ac = metrics.accuracy_score(y_test, y_pred)
            clas_report = classification_report(y_test, y_pred)
            
            ac_tuned = metrics.accuracy_score(y_test, y_pred_tuned)
            clas_report_tuned = classification_report(y_test, y_pred_tuned)
        

            print("Accuracy Score: {} \n\n*********************************\nClassification Report: \n{} \n\n <------------------------------->\n\n\nAccuracy Score Tuned: {} \n*********************************\nClassification Report Tuned: \n{}".format(ac, clas_report,ac_tuned, clas_report_tuned))
             
        
            
            preds = probs[:,1]
            fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
            roc_auc = metrics.auc(fpr, tpr)


        
            plt.title('Receiver Operating Characteristic')
            plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
            plt.legend(loc = 'lower right')
            plt.plot([0, 1], [0, 1],'r--')
            plt.xlim([0, 1])
            plt.ylim([0, 1])
            plt.ylabel('True Positive Rate')
            plt.xlabel('False Positive Rate')
            plt.show()  
            
            
        def MLP_Classifier_grid(self, y2):
        
            X_dummies = pd.get_dummies(self)
            X = X_dummies.drop([y2], axis = 1)
            y = self[y2] 
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42) 
            
            
            mlpc = MLPClassifier()
            mlpc_model = mlpc.fit(X_train, y_train)
            y_pred = mlpc_model.predict(X_test)
            
            grid_params = {
                    'alpha':[0.1,0.01,0.001,0.005,0.0001],
                    'hidden_layer_sizes': [(10,10,10),(30,50,60),(20,35,45),(50,15)],
                    'solver': ['lbfgs','adam','sgd']}
                           
                           
            mlpc_cv = GridSearchCV(mlpc, grid_params, n_jobs = -1, verbose = 2)
            mlpc_model_cv = mlpc_cv.fit(X_train, y_train)
                    
            parametre = []
            
            for i in mlpc_model_cv.best_params_:
                parametre.append(mlpc_model_cv.best_params_[i])
            
            mlpc_model_tuned = MLPClassifier(alpha = parametre[0],
                                                 hidden_layer_sizes = parametre[1],
                                                solver = parametre[2]).fit(X_train, y_train)
            
            y_pred_tuned = mlpc_model_tuned.predict(X_test)
            probs = mlpc_model.predict_proba(X_test)
        
        
        
    
        
            ac = metrics.accuracy_score(y_test, y_pred)
            clas_report = classification_report(y_test, y_pred)
            
            ac_tuned = metrics.accuracy_score(y_test, y_pred_tuned)
            clas_report_tuned = classification_report(y_test, y_pred_tuned)
        

            print("Accuracy Score: {} \n\n*********************************\nClassification Report: \n{} \n\n <------------------------------->\n\n\nAccuracy Score Tuned: {} \n*********************************\nClassification Report Tuned: \n{}".format(ac, clas_report,ac_tuned, clas_report_tuned))
             
        
            
            preds = probs[:,1]
            fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
            roc_auc = metrics.auc(fpr, tpr)


        
            plt.title('Receiver Operating Characteristic')
            plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
            plt.legend(loc = 'lower right')
            plt.plot([0, 1], [0, 1],'r--')
            plt.xlim([0, 1])
            plt.ylim([0, 1])
            plt.ylabel('True Positive Rate')
            plt.xlabel('False Positive Rate')
            plt.show()  
            
            

        def RandomForest_Classifier_grid(self, y2):
        
            X_dummies = pd.get_dummies(self)
            X = X_dummies.drop([y2], axis = 1)
            y = self[y2] 
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42) 
            
            
            rfc = RandomForestClassifier()
            rfc_model = rfc.fit(X_train, y_train)
            y_pred = rfc_model.predict(X_test)
            
            grid_params = {
                    "max_depth": [8,10,11,13,15,18],
                    "max_features": [5,10,15,20],
                     "n_estimators": [5,10,50,100,200,500],
                     "min_samples_split": [3,5,10],}
                           
                           
            rfc_cv = GridSearchCV(rfc, grid_params, n_jobs = -1, verbose = 2)
            rfc_model_cv = rfc_cv.fit(X_train, y_train)
                    
            parametre = []
            
            for i in rfc_model_cv.best_params_:
                parametre.append(rfc_model_cv.best_params_[i])
            
            rfc_model_tuned = RandomForestClassifier(max_depth = parametre[0],
                                                     max_features = parametre[1],
                                                 n_estimators = parametre[3],
                                                min_samples_split = parametre[2]).fit(X_train, y_train)
            
            y_pred_tuned = rfc_model_tuned.predict(X_test)
            probs = rfc_model.predict_proba(X_test)
        
        
        
    
        
            ac = metrics.accuracy_score(y_test, y_pred)
            clas_report = classification_report(y_test, y_pred)
            
            ac_tuned = metrics.accuracy_score(y_test, y_pred_tuned)
            clas_report_tuned = classification_report(y_test, y_pred_tuned)
        

            print("Accuracy Score: {} \n\n*********************************\nClassification Report: \n{} \n\n <------------------------------->\n\n\nAccuracy Score Tuned: {} \n*********************************\nClassification Report Tuned: \n{}".format(ac, clas_report,ac_tuned, clas_report_tuned))
             
        
            
            preds = probs[:,1]
            fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
            roc_auc = metrics.auc(fpr, tpr)


        
            plt.title('Receiver Operating Characteristic')
            plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
            plt.legend(loc = 'lower right')
            plt.plot([0, 1], [0, 1],'r--')
            plt.xlim([0, 1])
            plt.ylim([0, 1])
            plt.ylabel('True Positive Rate')
            plt.xlabel('False Positive Rate')
            plt.show()  
            
            

        
        
        
        
        
        
        
        
        def DecisionTree_Classifier_grid(self, y2):
        
            X_dummies = pd.get_dummies(self)
            X = X_dummies.drop([y2], axis = 1)
            y = self[y2] 
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42) 
            
            
            cartc = DecisionTreeClassifier()
            cartc_model = cartc.fit(X_train, y_train)
            y_pred = cartc_model.predict(X_test)
            
            grid_params = {"max_depth": range(1,10),
                    "min_samples_split": list(range(2,50)),
                    "criterion":['gini', 'entropy']}
                           
                           
            cartc_cv = GridSearchCV(cartc, grid_params, n_jobs = -1, verbose = 2)
            cartc_model_cv = cartc_cv.fit(X_train, y_train)
                    
            parametre = []
            
            for i in cartc_model_cv.best_params_:
                parametre.append(cartc_model_cv.best_params_[i])
            
            cartc_model_tuned = DecisionTreeClassifier(max_depth = parametre[1],
                                                     criterion = parametre[0],
                                                min_samples_split = parametre[2]).fit(X_train, y_train)
            
            y_pred_tuned = cartc_model_tuned.predict(X_test)
            probs = cartc_model.predict_proba(X_test)
        
        
        
    
        
            ac = metrics.accuracy_score(y_test, y_pred)
            clas_report = classification_report(y_test, y_pred)
            
            ac_tuned = metrics.accuracy_score(y_test, y_pred_tuned)
            clas_report_tuned = classification_report(y_test, y_pred_tuned)
        

            print("Accuracy Score: {} \n\n*********************************\nClassification Report: \n{} \n\n <------------------------------->\n\n\nAccuracy Score Tuned: {} \n*********************************\nClassification Report Tuned: \n{}".format(ac, clas_report,ac_tuned, clas_report_tuned))
             
        
            
            preds = probs[:,1]
            fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
            roc_auc = metrics.auc(fpr, tpr)


        
            plt.title('Receiver Operating Characteristic')
            plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
            plt.legend(loc = 'lower right')
            plt.plot([0, 1], [0, 1],'r--')
            plt.xlim([0, 1])
            plt.ylim([0, 1])
            plt.ylabel('True Positive Rate')
            plt.xlabel('False Positive Rate')
            plt.show()  
            
            
            
            
            
            
            
            
            
            
            
            # REGRESYON -------------------------- Grid
            
            
            
            
            
            
            
            

        def DecisionTree_Regressor_grid(self, y2):
        
            X_dummies = pd.get_dummies(self)
            X = X_dummies.drop([y2], axis = 1)
            y = self[y2] 
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42) 
            
            
            cartc = DecisionTreeRegressor()
            cartc_model = cartc.fit(X_train, y_train)
            y_pred = cartc_model.predict(X_test)
            
            grid_params = {"max_depth": range(1,10),
                    "min_samples_split": list(range(2,50)),
                    }
                           
                           
            cartc_cv = GridSearchCV(cartc, grid_params, n_jobs = -1, verbose = 2)
            cartc_model_cv = cartc_cv.fit(X_train, y_train)
                    
            parametre = []
            
            for i in cartc_model_cv.best_params_:
                parametre.append(cartc_model_cv.best_params_[i])
            
            cartc_model_tuned = DecisionTreeRegressor(max_depth = parametre[0],
                                                min_samples_split = parametre[1]).fit(X_train, y_train)
            
            y_pred_tuned = cartc_model_tuned.predict(X_test)
            
        
        
            mse = np.sqrt(mean_squared_error(y_test, y_pred))
            r2 = r2_score(y_test, y_pred)
        
            mse_tuned = np.sqrt(mean_squared_error(y_test, y_pred))
            r2_tuned = r2_score(y_test, y_pred)
        
        

            print("rmse: {} \nr2: {}\n\n <------------------------>\n rmse Tuned: {}\nr2 Tuned {}".format(mse,r2, mse_tuned, r2_tuned))        
            
        def RandomForest_Regressor_grid(self, y2):
        
            X_dummies = pd.get_dummies(self)
            X = X_dummies.drop([y2], axis = 1)
            y = self[y2] 
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42) 
            
            
            rfc = RandomForestRegressor()
            rfc_model = rfc.fit(X_train, y_train)
            y_pred = rfc_model.predict(X_test)
            
            grid_params = {
                    "max_depth": [8,10,11,13,15,18],
                    "max_features": [5,10,15,20],
                     "n_estimators": [5,10,50,100,200,500],
                     "min_samples_split": [3,5,10],}
                           
                           
            rfc_cv = GridSearchCV(rfc, grid_params, n_jobs = -1, verbose = 2)
            rfc_model_cv = rfc_cv.fit(X_train, y_train)
                    
            parametre = []
            
            for i in rfc_model_cv.best_params_:
                parametre.append(rfc_model_cv.best_params_[i])
            
            rfc_model_tuned = RandomForestRegressor(max_depth = parametre[0],
                                                     max_features = parametre[1],
                                                 n_estimators = parametre[3],
                                                min_samples_split = parametre[2]).fit(X_train, y_train)
            
            y_pred_tuned = rfc_model_tuned.predict(X_test)            
            
            mse = np.sqrt(mean_squared_error(y_test, y_pred))
            r2 = r2_score(y_test, y_pred)
        
            mse_tuned = np.sqrt(mean_squared_error(y_test, y_pred))
            r2_tuned = r2_score(y_test, y_pred)
        
        

            print("rmse: {} \nr2: {}\n\n <------------------------>\n rmse Tuned: {}\nr2 Tuned {}".format(mse,r2, mse_tuned, r2_tuned))        
            
            
        def K_N_N_regressor_grid(self, y2):
        
            X_dummies = pd.get_dummies(self)
            X = X_dummies.drop([y2], axis = 1)
            y = self[y2] 
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42) 
            
            
            knn = KNeighborsRegressor()
            knn_model = knn.fit(X_train, y_train)
            y_pred = knn_model.predict(X_test)
            
            grid_params = {'n_neighbors': np.arange(1, 40),
                                'metric': ['minkowski', 'euclidean', 'manhattan']}
            
            knn_cv = GridSearchCV(knn, grid_params, n_jobs = -1, verbose = 2)
            knn_model_cv = knn_cv.fit(X_train, y_train)
                    
            parametre = []
            
            for i in knn_model_cv.best_params_:
                parametre.append(knn_model_cv.best_params_[i])
            
            knn_model_tuned = KNeighborsRegressor(n_neighbors = parametre[1],
                                            metric = parametre[0]).fit(X_train, y_train)
            
            y_pred_tuned = knn_model_tuned.predict(X_test)
        
            mse = np.sqrt(mean_squared_error(y_test, y_pred))
            r2 = r2_score(y_test, y_pred)
        
            mse_tuned = np.sqrt(mean_squared_error(y_test, y_pred))
            r2_tuned = r2_score(y_test, y_pred)
        
        

            print("rmse: {} \nr2: {}\n\n <------------------------>\n rmse Tuned: {}\nr2 Tuned {}".format(mse,r2, mse_tuned, r2_tuned))   
        
        
        
        def CatBoost_Regressor_grid(self, y2):
        
            X_dummies = pd.get_dummies(self)
            X = X_dummies.drop([y2], axis = 1)
            y = self[y2] 
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42) 
            
            
            catbc = CatBoostRegressor()
            catbc_model = catbc.fit(X_train, y_train)
            y_pred = catbc_model.predict(X_test)
            
            grid_params = {'iterations': [200, 500],
                            'learning_rate': [0.01, 0.02, 0.05],
                            'depth': [3, 5, 8]}
            
            catbc_cv = GridSearchCV(catbc, grid_params, n_jobs = -1, verbose = 2)
            catbc_model_cv = catbc_cv.fit(X_train, y_train)
                    
            parametre = []
            
            for i in catbc_model_cv.best_params_:
                parametre.append(catbc_model_cv.best_params_[i])
            
            catbc_model_tuned = CatBoostRegressor(iterations = parametre[2],
                                            learning_rate = parametre[1],
                                                  depth= parametre[0]).fit(X_train, y_train)
            
            y_pred_tuned = catbc_model_tuned.predict(X_test)
            
            
            
            y_pred_tuned = knn_model_tuned.predict(X_test)
        
            mse = np.sqrt(mean_squared_error(y_test, y_pred))
            r2 = r2_score(y_test, y_pred)
        
            mse_tuned = np.sqrt(mean_squared_error(y_test, y_pred))
            r2_tuned = r2_score(y_test, y_pred)
        
        

            print("rmse: {} \nr2: {}\n\n <------------------------>\n rmse Tuned: {}\nr2 Tuned {}".format(mse,r2, mse_tuned, r2_tuned))   
        
        
            
            
        def LGBM_Regressor_grid(self, y2):
        
            X_dummies = pd.get_dummies(self)
            X = X_dummies.drop([y2], axis = 1)
            y = self[y2] 
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42) 
            
            
            lgbmc = LGBMRegressor()
            lgbmc_model = lgbmc.fit(X_train, y_train)
            y_pred = lgbmc_model.predict(X_test)
            
            grid_params = {'subsample': [0.6, 0.8, 1.0],
                               'n_estimators': [100, 500, 1000, 1500],
                               'max_depth': [4, 5, 6, 7],
                               'min_child_samples': [10, 20],
                               'learning_rate': [0.2, 0.1, 0.01, 0.02, 0.05]}
            
            lgbmc_cv = GridSearchCV(lgbmc, grid_params, n_jobs = -1, verbose = 2)
            lgbmc_model_cv = lgbmc_cv.fit(X_train, y_train)
                    
            parametre = []
            
            for i in lgbmc_model_cv.best_params_:
                parametre.append(lgbmc_model_cv.best_params_[i])
            
            lgbmc_model_tuned = LGBMRegressor(subsample = parametre[4],
                                            n_estimators = parametre[3],
                                                  max_depth= parametre[1],
                                                  min_child_samples= parametre[2],
                                                 learning_rate= parametre[0]).fit(X_train, y_train)
            
            y_pred_tuned = lgbmc_model_tuned.predict(X_test)
            
        
            mse = np.sqrt(mean_squared_error(y_test, y_pred))
            r2 = r2_score(y_test, y_pred)
        
            mse_tuned = np.sqrt(mean_squared_error(y_test, y_pred))
            r2_tuned = r2_score(y_test, y_pred)
        
        

            print("rmse: {} \nr2: {}\n\n <------------------------>\n rmse Tuned: {}\nr2 Tuned {}".format(mse,r2, mse_tuned, r2_tuned))   
        
        
            
            
        def XGB_Regressor_grid(self, y2):
        
            X_dummies = pd.get_dummies(self)
            X = X_dummies.drop([y2], axis = 1)
            y = self[y2] 
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42) 
            
            
            xgbc = XGBRegressor()
            xgbc_model = xgbc.fit(X_train, y_train)
            y_pred = xgbc_model.predict(X_test)
            
            grid_params = {'colsample_bytree':[0.6,1.0],
                        'n_estimators':[100,200,500,1000],
                        'max_depth':[4,5,6, 7],
                        'min_child_weight':[0.8,0.9,1],
                        'learning_rate': [0.1,0.01,0.02,0.05]}
            
            xgbc_cv = GridSearchCV(xgbc, grid_params, n_jobs = -1, verbose = 2)
            xgbc_model_cv = xgbc_cv.fit(X_train, y_train)
                    
            parametre = []
            
            for i in xgbc_model_cv.best_params_:
                parametre.append(xgbc_model_cv.best_params_[i])
            
            xgbc_model_tuned = XGBRegressor(colsample_bytree = parametre[0],
                                            n_estimators = parametre[4],
                                                  max_depth= parametre[2],
                                                  min_child_weight= parametre[3],
                                                 learning_rate= parametre[1]).fit(X_train, y_train)
            
            y_pred_tuned = xgbc_model_tuned.predict(X_test)
            
            
            mse = np.sqrt(mean_squared_error(y_test, y_pred))
            r2 = r2_score(y_test, y_pred)
        
            mse_tuned = np.sqrt(mean_squared_error(y_test, y_pred))
            r2_tuned = r2_score(y_test, y_pred)
        
        

            print("rmse: {} \nr2: {}\n\n <------------------------>\n rmse Tuned: {}\nr2 Tuned {}".format(mse,r2, mse_tuned, r2_tuned))   
            
        def GradientBoosting_Regressor_grid(self, y2):
        
            X_dummies = pd.get_dummies(self)
            X = X_dummies.drop([y2], axis = 1)
            y = self[y2] 
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42) 
            
            
            gbc = GradientBoostingRegressor()
            gbc_model = gbc.fit(X_train, y_train)
            y_pred = gbc_model.predict(X_test)
            
            grid_params = {'learning_rate': [0.001, 0.01, 0.1, 0.2, 0.3],
                            'n_estimators': [100, 500, 1000, 1500],
                            'max_depth': [3, 5, 6],
                            'min_samples_split': [2, 5, 10, 15],
                            'subsample':[0.6,1.0]}
            
            gbc_cv = GridSearchCV(gbc, grid_params, n_jobs = -1, verbose = 2)
            gbc_model_cv = gbc_cv.fit(X_train, y_train)
                    
            parametre = []
            
            for i in gbc_model_cv.best_params_:
                parametre.append(gbc_model_cv.best_params_[i])
            
            gbc_model_tuned = GradientBoostingRegressor(learning_rate = parametre[0],
                                            n_estimators = parametre[3],
                                                  max_depth = parametre[1],
                                                  min_samples_split = parametre[2],
                                                 subsample = parametre[4]).fit(X_train, y_train)
            
            y_pred_tuned = gbc_model_tuned.predict(X_test)
            
            
            mse = np.sqrt(mean_squared_error(y_test, y_pred))
            r2 = r2_score(y_test, y_pred)
        
            mse_tuned = np.sqrt(mean_squared_error(y_test, y_pred))
            r2_tuned = r2_score(y_test, y_pred)
        
        

            print("rmse: {} \nr2: {}\n\n <------------------------>\n rmse Tuned: {}\nr2 Tuned {}".format(mse,r2, mse_tuned, r2_tuned))
            
        def S_V_R_grid(self, y2):
        
            X_dummies = pd.get_dummies(self)
            X = X_dummies.drop([y2], axis = 1)
            y = self[y2] 
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42) 
            
            
            s_vr = SVR()
            s_vr_model = s_vr.fit(X_train, y_train)
            y_pred = s_vr_model.predict(X_test)
            
            grid_params = {"kernel": ["linear", 'poly', 'rbf'],
                             "C": [1,2,3,6,8]}
            
            s_vr_cv = GridSearchCV(s_vr, grid_params, n_jobs = -1, verbose = 2)
            s_vr_model_cv = s_vr_cv.fit(X_train, y_train)
                    
            parametre = []
            
            for i in s_vr_model_cv.best_params_:
                parametre.append(s_vr_model_cv.best_params_[i])
            
            s_vr_model_tuned = SVR(kernel = parametre[1],
                                            C = parametre[0]).fit(X_train, y_train)
            
            y_pred_tuned = s_vr_model_tuned.predict(X_test)
            
            
            mse = np.sqrt(mean_squared_error(y_test, y_pred))
            r2 = r2_score(y_test, y_pred)
        
            mse_tuned = np.sqrt(mean_squared_error(y_test, y_pred))
            r2_tuned = r2_score(y_test, y_pred)
        
        

            print("rmse: {} \nr2: {}\n\n <------------------------>\n rmse Tuned: {}\nr2 Tuned {}".format(mse,r2, mse_tuned, r2_tuned)) 
            
            
        def MLP_Regressor_grid(self, y2):
        
            X_dummies = pd.get_dummies(self)
            X = X_dummies.drop([y2], axis = 1)
            y = self[y2] 
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42) 
            
            
            mlpc = MLPRegressor()
            mlpc_model = mlpc.fit(X_train, y_train)
            y_pred = mlpc_model.predict(X_test)
            
            grid_params = {
                    'alpha':[0.1,0.01,0.001,0.005],
                    'hidden_layer_sizes': [(10,10,10),(30,50,60),(20,35,45),(50,15)],
                    'solver': ['lbfgs','adam','sgd']}
                           
                           
            mlpc_cv = GridSearchCV(mlpc, grid_params, n_jobs = -1, verbose = 2)
            mlpc_model_cv = mlpc_cv.fit(X_train, y_train)
                    
            parametre = []
            
            for i in mlpc_model_cv.best_params_:
                parametre.append(mlpc_model_cv.best_params_[i])
            
            mlpc_model_tuned = MLPRegressor(alpha = parametre[0],
                                                 hidden_layer_sizes = parametre[1],
                                                solver = parametre[2]).fit(X_train, y_train)
            
            y_pred_tuned = mlpc_model_tuned.predict(X_test)
            
            
            mse = np.sqrt(mean_squared_error(y_test, y_pred))
            r2 = r2_score(y_test, y_pred)
        
            mse_tuned = np.sqrt(mean_squared_error(y_test, y_pred))
            r2_tuned = r2_score(y_test, y_pred)
        
        

            print("rmse: {} \nr2: {}\n\n <------------------------>\n rmse Tuned: {}\nr2 Tuned {}".format(mse,r2, mse_tuned, r2_tuned))

# %%
df_class = pd.read_csv("hmelq.csv")
df_class.head(5)
# Out:
#    bad   loan   mortdue     value   reason  job   yoj  derog  delinq   clage  \
# 0    0  81200   18834.0  108355.0  HomeImp  NaN  28.0    0.0     0.0  139.14
# 1    0  12600  103960.0  127384.0  DebtCon  NaN   2.0    0.0     0.0  129.02
# 2    0  18000   46865.0   61266.0  DebtCon  NaN   5.0    0.0     0.0  102.59
# 3    0  10300   57676.0   71027.0  DebtCon  NaN  19.0    0.0     0.0  157.52
# 4    0   9400   56508.0   78358.0  DebtCon  NaN  17.0    0.0     0.0  141.93
#
#    ninq  clno  debtinc
# 0   0.0  14.0   34.042
# 1   0.0  25.0   34.479
# 2   2.0   9.0   26.354
# 3   1.0  11.0   33.992
# 4   0.0  11.0   32.327

# %%
df_reg = pd.read_excel("HW_Data_Set.xlsx")
df_reg.head(5)
# Out:
#    ind_5  ind_6  ind_8      ind_9     ind_10     ind_12     ind_13  ind_14  \
# 0     19     17  100.0  85.714286  14.285714  72.363515  60.808814   23.80
# 1     24     19  100.0  78.571429  21.428571  74.275883  64.366798   11.45
# 2     30     24  100.0  71.428571  28.571429  75.140402  65.915803    8.75
# 3     37     30  100.0  64.285714  35.714286  76.677846  68.584234    7.80
# 4     41     37  100.0  57.142857  42.857143  81.603007  76.455495   14.90
#
#    ind_15  ind_16  ...  ind_416  ind_418  ind_420  ind_422  ind_424   ind_426  \
# 0   17.62   11.73  ...    -49.6      -54     -152     -353      1.0  0.498547
# 1   18.16   12.22  ...    -55.6      -60     -158     -359      1.0  0.537088
# 2   17.86   12.28  ...    -58.4      -60     -160     -362      1.0  0.615169
# 3   14.76   12.61  ...    -61.8      -65     -166     -367      1.0  0.661517
# 4   11.92   14.25  ...    -79.8      -86     -186     -388      1.0  0.747204
#
#     ind_428  20_target  50_target  90_target
# ...

# %% [markdown]
# # ÖRNEKLER

# %%
df_class_bos = duzenleme.bos_gozlem(df_class)
df_reg_bos = duzenleme.bos_gozlem(df_reg)

print(df_class_bos , df_reg_bos)
# Out:
# bad          0
# loan         0
# mortdue    314
# value       64
# reason     147
# job        167
# yoj        312
# derog      427
# delinq     351
# clage      179
# ninq       303
# clno       133
# debtinc    767
# dtype: int64
# ind_5        0
# ind_6        0
# ind_8        0
# ind_9        0
# ind_10       0
#             ..
# ind_426      0
# ind_428      0
# 20_target    0
# 50_target    0
# 90_target    0
# Length: 136, dtype: int64
# None None

# %%
duzenleme.bos_kaldir(df_reg)
duzenleme.bos_kaldir(df_class)

# %%
gorsel.kutu("bad","loan",df_class)

# %% [markdown]
# # PCA Ve Kümeleme

# %%
model_oncesi.P_C_A(df_class, "bad", 10)
# Out:
# [14.19 25.66 34.77 42.12 48.98 55.39 61.6  67.14 72.16 76.96]

# %%
model_oncesi.optimum_kume(df_class)

# %%
model_oncesi.kumeleme_pca(df_reg, 4, 10)
# Out:
# Kümeler: [2 2 2 ... 2 2 2]
#
#  Merkezler: [[-2.33200894  3.4459333  -0.39356271 -1.11561208 -0.20729161 -0.17675169
#    0.38574393  0.05158334  0.15296996 -0.01636139]
#  [ 1.53060368 -3.09699893 -0.69376495 -0.35112382  0.67791662  0.12915696
#   -0.30004091 -0.13528756 -0.28929282 -0.03419703]
#  [-9.25574908 -0.61098218  0.67546173  1.04682443 -0.36959384  0.02245494
#    0.04700736  0.18430414  0.27890132 -0.02908489]
#  [ 9.17250969  1.2398804   0.77175036  0.71595763 -0.38700382 -0.01289109
#   -0.0374489  -0.0391452  -0.02040397  0.09413765]]

# %%
model_oncesi.kumeleme(df_reg, 6)
# Out:
# Kümeler: [2 2 2 ... 4 2 2]
#
#  Merkezler: [[-2.19258555e+01 -2.30256654e+01  2.04644215e+01 ...  2.85171103e-03
#   -4.01154804e-18  1.30228137e-01]
#  [-3.63051823e+00 -1.78502879e+00  3.35001371e+01 ... -1.31188463e-17
#   -3.95733793e-18  2.14971209e-01]
#  [ 2.33250743e+01  2.08800793e+01  8.64859125e+01 ... -1.29020059e-17
#   -3.84891771e-18  1.72447968e-01]
#  [ 1.39700079e-01 -1.68666140e+00  6.13034164e+01 ... -1.42030485e-17
#   -4.66206934e-18  1.55485399e-01]
#  [ 2.03726899e+01  2.17340862e+01  5.61674978e+01 ... -1.26851654e-17
#   -3.68628739e-18  1.79671458e-01]
#  [-2.63171324e+01 -2.30522479e+01  2.71393855e+01 ...  2.43013366e-03
#    2.43013366e-03  1.62818955e-01]]

# %% [markdown]
# # classfication

# %%
classfication_problemi.Logistic_regression(df_class, "bad")
# Out:
# Accuracy Score: 0.9133663366336634
# Confusion Matrix:
# [[369   0]
#  [ 35   0]]
# *********************************
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95       369
#            1       0.00      0.00      0.00        35
#
#     accuracy                           0.91       404
#    macro avg       0.46      0.50      0.48       404
# weighted avg       0.83      0.91      0.87       404

# %%
classfication_problemi.GradientBoosting_Classifier(df_class, "bad")
# Out:
# Accuracy Score: 0.9455445544554455
# Confusion Matrix:
# [[368   1]
#  [ 21  14]]
# *********************************
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97       369
#            1       0.93      0.40      0.56        35
#
#     accuracy                           0.95       404
#    macro avg       0.94      0.70      0.77       404
# weighted avg       0.94      0.95      0.94       404

# %%
classfication_problemi.MLP_Classifier(df_class, "bad")
# Out:
# Accuracy Score: 0.9034653465346535
# Confusion Matrix:
# [[363   6]
#  [ 33   2]]
# *********************************
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95       369
#            1       0.25      0.06      0.09        35
#
#     accuracy                           0.90       404
#    macro avg       0.58      0.52      0.52       404
# weighted avg       0.86      0.90      0.87       404

# %% [markdown]
# # Regresyon

# %%
regressor_problemi.CatBoost_Regressor(df_reg, "50_target")
# Out:
# rmse: 9.751937171176987
# r2: 0.9200195421874127

# %%
regressor_problemi.KNeighbors_Regressor(df_reg, "50_target")
# Out:
# rmse: 20.84490517758243
# r2: 0.634571896247039

# %%
regressor_problemi.S_V_R(df_reg, "50_target")
# Out:
# rmse: 23.332407663596992
# r2: 0.5421521193784414

# %% [markdown]
# # Tuned edilmiş Regresyon Ve Sınıflandırma

# %%
Grid_Search.DecisionTree_Classifier_grid(df_class, "bad")
# Out:
# Fitting 5 folds for each of 864 candidates, totalling 4320 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=-1)]: Done 3276 tasks      | elapsed:    8.8s
# Accuracy Score: 0.9381188118811881
#
# *********************************
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97       369
#            1       0.75      0.43      0.55        35
#
#     accuracy                           0.94       404
#    macro avg       0.85      0.71      0.76       404
# weighted avg       0.93      0.94      0.93       404
#
#
#  <------------------------------->
#
#
# Accuracy Score Tuned: 0.948019801980198
# *********************************
# Classification Report Tuned:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97       369
# ...

# %%
Grid_Search.K_N_N_grid(df_class, "bad")
# Out:
# Fitting 5 folds for each of 117 candidates, totalling 585 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 128 tasks      | elapsed:    0.9s
# Accuracy Score: 0.9158415841584159
#
# *********************************
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.96       369
#            1       0.57      0.11      0.19        35
#
#     accuracy                           0.92       404
#    macro avg       0.75      0.55      0.57       404
# weighted avg       0.89      0.92      0.89       404
#
#
#  <------------------------------->
#
#
# Accuracy Score Tuned: 0.9183168316831684
# *********************************
# Classification Report Tuned:
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96       369
#            1       1.00      0.06      0.11        35
#
# ...

# %%
Grid_Search.XGB_Classifier_grid(df_class, "bad")
# Out:
# Fitting 5 folds for each of 384 candidates, totalling 1920 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:   20.4s
# [Parallel(n_jobs=-1)]: Done 357 tasks      | elapsed:   49.8s
# [Parallel(n_jobs=-1)]: Done 640 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 1005 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 1450 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=-1)]: Done 1920 out of 1920 | elapsed:  6.3min finished
# Accuracy Score: 0.9579207920792079
#
# *********************************
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98       369
#            1       0.95      0.54      0.69        35
#
#     accuracy                           0.96       404
#    macro avg       0.95      0.77      0.83       404
# ...

# %%
Grid_Search.DecisionTree_Regressor_grid(df_reg, "50_target")
# Out:
# Fitting 5 folds for each of 432 candidates, totalling 2160 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  58 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done 300 tasks      | elapsed:   14.1s
# [Parallel(n_jobs=-1)]: Done 706 tasks      | elapsed:   42.6s
# [Parallel(n_jobs=-1)]: Done 1272 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 1757 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 2160 out of 2160 | elapsed:  3.6min finished
# rmse: 12.12447333711672
# r2: 0.876368863339552
#
#  <------------------------>
#  rmse Tuned: 12.12447333711672
# r2 Tuned 0.876368863339552

# %%
Grid_Search.K_N_N_regressor_grid(df_reg, "50_target")
# Out:
# Fitting 5 folds for each of 117 candidates, totalling 585 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   44.1s
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done 357 tasks      | elapsed:  8.0min
# [Parallel(n_jobs=-1)]: Done 585 out of 585 | elapsed: 14.2min finished
# rmse: 20.84490517758243
# r2: 0.634571896247039
#
#  <------------------------>
#  rmse Tuned: 20.84490517758243
# r2 Tuned 0.634571896247039
